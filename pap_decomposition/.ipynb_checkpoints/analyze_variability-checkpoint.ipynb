# %%
import pandas as pd
import math
from copy import deepcopy
import os
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from numpy.random import lognormal, exponential, uniform
from scipy.optimize import curve_fit
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Import data

# %%
df = pd.read_excel("PAP_repeats_micafungin.xlsx").drop(64, axis=1).dropna().sort_values(['Strain','Replicate']).reset_index(drop=True)
df['Strain']= [str(x)+'_'+str(y) for x,y in zip(df.Strain, df.Replicate)]
df = df.drop('Replicate', axis=1).set_index('Strain').T
for col in df.columns:
    df.loc[df[col]==0,col] = 0.0001
df
# Out:
# Strain        65_1        65_2       65_4       65_5        67_1        67_4  \
# 0       100.000000  100.000000  100.00000  100.00000  100.000000  100.000000
# 1         2.500000    0.040000    2.50000   10.00000    0.888889    6.666667
# 2         0.025000    0.033333    0.02500    0.05000    0.033333    0.033333
# 4         0.025000    0.036667    0.00275    0.00500    0.111111    0.006667
# 8         0.008333    0.016667    0.00050    0.00025    0.005556    0.000667
# 16        0.016667    0.003333    0.00025    0.00050    0.013333    0.000667
# 32        0.012500    0.033333    0.00050    0.00010    0.012222    0.000100
#
# Strain        67_5    478_1       478_4      478_5  ...    2386_2    2386_3  \
# 0       100.000000  100.000  100.000000  100.00000  ...  100.0000  100.0000
# 1         6.666667    0.060    5.333333    5.00000  ...    0.0001    0.0001
# 2         0.020000    0.045    0.026667    0.05000  ...    0.0001    0.0001
# ...

# %%
df.to_csv("PAP_repeats_micafungin_cleaned.csv")
